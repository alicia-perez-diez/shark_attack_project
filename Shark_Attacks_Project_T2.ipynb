# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/Quest_Shark_Attacks')

# %%
from functions_T2 import *

# %%
from graph_functions_T_2 import *

# %%
df = data_upload_and_cleaning("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
df_ultimos_anyos = last_10_years_data_calculator(df)

# %%
df_ultimos_anyos = week_day_and_month_calculator(df_ultimos_anyos)
# Out:
# /content/drive/MyDrive/Quest_Shark_Attacks/functions_T2.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ultimos_anyos['week_day'] = df_ultimos_anyos['date'].dt.day_name(locale='')
# /content/drive/MyDrive/Quest_Shark_Attacks/functions_T2.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ultimos_anyos["month"] = df_ultimos_anyos["date"].dt.month

# %%
df
# Out:
#            date    year        type    country              state  \
# 0    2024-03-15  2024.0  Unprovoked  Australia         Queensland
# 1    2024-03-04  2024.0  Unprovoked        Usa             Hawaii
# 2    2024-03-02  2024.0  Unprovoked        Usa             Hawaii
# 3    2024-02-25  2024.0  Unprovoked  Australia  Western Australia
# 4    2024-02-14  2024.0  Unprovoked      India        Maharashtra
# ...         ...     ...         ...        ...                ...
# 6774 1784-12-12  1784.0  Unprovoked    Jamaica                NaN
# 6776 1780-08-08  1780.0  Unprovoked        Usa            Florida
# 6785 1751-07-27  1751.0  Unprovoked        Usa      Massachusetts
# 6789 1742-12-17  1742.0  Unprovoked        NaN                NaN
# 6794 1703-03-26  1703.0  Unprovoked   Barbados    Southwest coast
#
#                                location  activity  \
# 0                         Bargara Beach  Swimming
# 1                    Old Man's, Waikiki   Surfing
# ...

# %%
df_ultimos_anyos
# Out:
#            date    year        type       country                  state  \
# 0    2024-03-15  2024.0  Unprovoked     Australia             Queensland
# 1    2024-03-04  2024.0  Unprovoked           Usa                 Hawaii
# 2    2024-03-02  2024.0  Unprovoked           Usa                 Hawaii
# 3    2024-02-25  2024.0  Unprovoked     Australia      Western Australia
# 4    2024-02-14  2024.0  Unprovoked         India            Maharashtra
# ...         ...     ...         ...           ...                    ...
# 1072 2015-01-17  2015.0  Watercraft     Australia        New South Wales
# 1073 2015-01-16  2015.0  Unprovoked     Australia        New South Wales
# 1075 2015-01-06  2015.0  Unprovoked       Bahamas          Abaco Islands
# 1076 2015-01-03  2015.0  Unprovoked  South Africa  Eastern Cape Province
# 1077 2015-01-01  2015.0  Unprovoked           Usa                Florida
#
#                                 location    activity  \
# ...

# %%
sharks_seen_evolution_heatmap(df_ultimos_anyos)

# %%
top_week_day_graph(df_ultimos_anyos)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
number_of_sharks_per_country_graph(df_ultimos_anyos)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
number_of_sharks_per_state_graph(df_ultimos_anyos)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
number_of_sharks_per_location_graph(df_ultimos_anyos)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_species_graph(df_ultimos_anyos)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
